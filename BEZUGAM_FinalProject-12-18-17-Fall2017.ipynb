# %% [markdown]
# # Comparision of Google,Yahoo and Bing Search Engines

# %% [markdown]
# Why did I choose to do this project?

# %% [markdown]
# ## Introduction

# %% [markdown]
# Search Engine

# %%
from IPython.display import Image
Image(filename='searchengine_flow.png')

# %% [markdown]
# ## GOOGLE

# %% [markdown]
# How does google work?

# %% [markdown]
# >Crawling and Indexing
# >Search Algorithms
# >Useful Responses
# >Google ranking considers about 200 factors.Few of them are
# keyword in title tage,
# most frequently  used phrase in document,
# Latent Semantic Indexing Keywords in Content (LSI),
# page loading speed,
# outbound links and inbound links,
# broken links(-ve)
# Page Rank Algorithm
# References and sources
# Trust Rank
# Site Reputation
# Social Signal Relevancy
# Redirects(-ve)

# %% [markdown]
#  Bing, Google and Yahoo are the three leading world-class English search engines.

# %%
Google has tools such as street views and is known for giving solid search results

# %% [markdown]
# ## Bing

# %% [markdown]
#  Bing has excellent search tools such as explorer pane, quick previews and sentiment extraction

# %% [markdown]
# Ranking Factors:
#
# User Engagement
# Click Through Rates
# Social Signals(embeds posts from twitter and facebook in search results)
# Backlinks Are Less Important
# Inbound anchor tags are important
# Content & Keyword Density Is Important
# HTTPS Is Not Part Of Bing Ranking Factors

# %% [markdown]
# ## Yahoo

# %% [markdown]
# Is known to integrate its search results with strong networks, enabling you to get more than web search results
# Concentrates on Page Content
# Mostly helpful for descriptive page titles and page content>Mostly text matching

# %% [markdown]
# Not good at determining if a link is a natural citation or not.
# Paid inclusion program. both of which give them incentive to bias search results toward commercial results
# things like cheesy off topic reciprocal links still work great in Yahoo!

# %% [markdown]
# ## History Comparision

# %%
import matplotlib.pyplot as plt;
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('Google', 'Bing', 'yahoo')
y_pos = np.arange(len(objects))
age= [17,20,6]
 
plt.bar(y_pos, age, align='center', alpha=1.0)
plt.xticks(y_pos, objects)
plt.ylabel('Age')
plt.title('Search engines')
 
plt.show()

# %% [markdown]
# ## Comparisions of Pages indexed:

# %%
import matplotlib.pyplot as plt;
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('Google', 'Bing', 'yahoo')
y_pos = np.arange(len(objects))
performance = [40,13.5,10]
 
plt.bar(y_pos, performance, align='center', alpha=1.0)
plt.xticks(y_pos, objects)
plt.ylabel('Index Size in billions')
plt.title('Search engines')
 
plt.show()

# %% [markdown]
# ## Displays results count

# %% [markdown]
# google:resultStats
#
# bing:sb_count

# %% [markdown]
# # Other Factors:

# %% [markdown]
# Tracking IP Address,nformation sharing.
#
# Only Yahoo has partial dedicated servers.Google and Bing have their own dedicated servers.

# %% [markdown]
# # Challenges

# %%
I haved planned to compare the search results of the 3 search engines.

I have tried to install the modules from the python.All those installations failed.I had to re install anaconda for many times.

Then I have thought of extracting links from the view source page of each search engine.In that process I have learned about beautiful Soup.

# %% [markdown]
# Exploring beautiful soup for parsing html pages

# %%
# %%cmd
# pip install beautifulsoup4
# Out:
# Microsoft Windows [Version 10.0.16299.125]
# (c) 2017 Microsoft Corporation. All rights reserved.
#
# (C:\Users\AsusGo\Anaconda3) C:\Users\AsusGo\Downloads>pip install beautifulsoup4
# ...
#
# (C:\Users\AsusGo\Anaconda3) C:\Users\AsusGo\Downloads>

# %% [markdown]
# Exploring Beautiful Soup

# %%
import requests

page = requests.get("https://www.google.co.in/search?source=hp&ei=_sQ2WoXLE4OKmQHSjq3IDQ&q=gmail&oq=gmail&gs_l=psy-ab.3..0l2j0i131k1j0l7.1125.2114.0.2440.5.4.0.1.1.0.118.322.3j1.4.0....0...1c.1.64.psy-ab..0.5.327....0.27UfFmuCQd4.html")
page
# Out:
# <Response [200]>

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><link href="/images/branding/product/ico/googleg_lodp.ico" rel="shortcut icon"><title>gmail - Google Search</title><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important} </style><style>.star{float:left;margin-top:1px;overflow:hidden}._yhd{font-size:11px}.j{width:34em}body,td,div,.p,a{font-family:arial,sans-serif;tap-hi
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <link href="/images/branding/product/ico/googleg_lodp.ico" rel="shortcut icon"/>
#   <title>
#    gmail - Google Search
#   </title>
#   <style>
#    #gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
#   </style>
#   <style>
# ...

# %%
list(soup.children)
# Out:
# [u'doctype html',
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.Tag]

# %%
html = list(soup.children)[1]

# %%
list(html.children)
# Out:
# [<head><meta content="text/html; charset=unicode-escape" http-equiv="Content-Type"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><link href="/images/branding/product/ico/googleg_lodp.ico" rel="shortcut icon"/><title>gmail - Google Search</title><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important} </style><style>.star{float:left;margin-top:1px;overflow:hidden}._yhd{font-size:11px}.j{width:34em}body,td,div,.p,a{font-family:arial,sans-serif;tap-highlight-color:rgba(255,255,255,0)}body{margin:0}a img{border:0}#gbar{float:left
# ...

# %%
body = list(html.children)[1]

# %%
list(body.children)
# Out:
# [<div id="gbar"><nobr><b class="gb1">Search</b> <a class="gb1" href="https://www.google.com/search?hl=en&amp;tbm=isch&amp;source=og&amp;tab=wi">Images</a> <a class="gb1" href="https://maps.google.com/maps?hl=en&amp;tab=wl">Maps</a> <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=w8">Play</a> <a class="gb1" href="https://www.youtube.com/results?gl=US&amp;tab=w1">YouTube</a> <a class="gb1" href="https://news.google.com/nwshp?hl=en&amp;tab=wn">News</a> <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class="gb1" href="https://drive.google.com/?tab=wo">Drive</a> <a class="gb1" href="https://www.google.com/intl/en/options/" style="text-decoration:none"><u>More</u> \xbb</a></nobr></div>,
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('div', class_='_Zkb')
# Out:
# []

# %%
soup.find_all(id="resultStats")
# Out:
# [<div class="sd" id="resultStats">About 1,370,000,000 results</div>]

# %%
soup.find_all('nobr')
str(soup.find('nobr')).replace("<nobr>"," ").replace("</h2>"," ")
# Out:
# ' <b class="gb1">Search</b> <a class="gb1" href="https://www.google.com/search?hl=en&amp;tbm=isch&amp;source=og&amp;tab=wi">Images</a> <a class="gb1" href="https://maps.google.com/maps?hl=en&amp;tab=wl">Maps</a> <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=w8">Play</a> <a class="gb1" href="https://www.youtube.com/results?gl=US&amp;tab=w1">YouTube</a> <a class="gb1" href="https://news.google.com/nwshp?hl=en&amp;tab=wn">News</a> <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class="gb1" href="https://drive.google.com/?tab=wo">Drive</a> <a class="gb1" href="https://www.google.com/intl/en/options/" style="text-decoration:none"><u>More</u> \xc2\xbb</a></nobr>'

# %%
This code failed because yschttl class does not exsist.

# %%
import requests
from bs4 import BeautifulSoup
url = "http://search.yahoo.com/search?p=%s"
query = "python"
r = requests.get(url % query) 
soup = BeautifulSoup(r.text)
soup.find_all(attrs={"class": "yschttl"})

for link in soup.find_all(attrs={"class": "yschttl"}):
    print "%s (%s)" %(link.text, link.get('href'))

# %%
Bing but failed

# %%
import re
try:
    import urllib.request as urllib2
except ImportError:
    import urllib2
from bs4 import BeautifulSoup
import requests
import urllib
address = "http://www.bing.com/search?q=%s" 
getRequest = urllib2.Request(address, None, {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:54.0) Gecko/20100101 Firefox/54.0'})

urlfile = urllib2.urlopen(getRequest)
htmlResult = urlfile.read(200000)
urlfile.close()
soup = BeautifulSoup(htmlResult,'parse.html')

# get the results count
num_results = soup.find('span', class_=re.compile('resultNum')).text
num_results = int(re.search('(\d+)', num_results).group(1))
print ("Results found: " + str(num_results))
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-23-57d7bc64e6c8> in <module>()
#      13 htmlResult = urlfile.read(200000)
#      14 urlfile.close()
# ---> 15 soup = BeautifulSoup(htmlResult,'parse.html')
#      16
#      17 # get the results count
#
# C:\Users\AsusGo\Anaconda2\lib\site-packages\bs4\__init__.pyc in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     163                     "Couldn't find a tree builder with the features you "
#     164                     "requested: %s. Do you need to install a parser library?"
# --> 165                     % ",".join(features))
#     166             builder = builder_class()
#     167             if not (original_features == builder.NAME or
#
# ...

# %%
from bs4 import BeautifulSoup
try:
    import urllib.request as urllib2
except ImportError:
    import urllib2
import urllib

def search(query):
    address = "http://www.bing.com/search?q=%s" % (urllib.quote_plus(query))

    getRequest = urllib2.Request(address, None, {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:54.0) Gecko/20100101 Firefox/54.0'})

    urlfile = urllib2.urlopen(getRequest)
    htmlResult = urlfile.read(200000)
    urlfile.close()

    soup = BeautifulSoup(htmlResult)

    [s.extract() for s in soup('span')]
    unwantedTags = ['a', 'strong', 'cite']
    for tag in unwantedTags:
        for match in soup.findAll(tag):
            match.replaceWithChildren()

    results = soup.findAll('li', { "class" : "b_algo" })
    for result in results:
            print " " + str(result.find('h2')).replace(" "," ") + "\n"


    return results

if __name__=='__main__':
    links = search('excel')
# Out:
#  <h2>Excel 2016 by Microsoft - Spreadsheet Software | Office</h2>
#
#  <h2>Microsoft Excel Online - Work together on Excel …</h2>
#
#  <h2>Microsoft Excel - Android Apps on Google Play</h2>
#
#  <h2>What's new in Excel 2016 for Windows - Excel</h2>
#
#  <h2>Microsoft Office Excel 2010 - Free download and …</h2>
#
#  <h2>January 3, 2017, update for Excel 2016 (KB3141472)</h2>

# %%
try:
    import urllib.request as urllib2
except ImportError:
    import urllib2

import urllib
import json

url = "http://ajax.googleapis.com/ajax/services/search/web?v=1.0&"

query = input("What do you want to search for ? >> ")

query = urllib.parse.urlencode( {'q' : query } )

response = urllib2.urlopen (url + query ).read()

data = json.loads ( response )

results = data [ 'responseData' ] [ 'results' ]

for result in results:
    title = result['title']
    url = result['url']
    print ( title + '; ' + url )

# %%
# %%cmd
# pip install yahooboss

# %%
# %%cmd
# pip install googlesearch

# %%
Tried googlesearch.googlesearch but did not work

# %%
from googlesearch.googlesearch import GoogleSearch
response = GoogleSearch().search("something")
for result in response.results:
    print("Title: " + result.title)
    print("Content: " + result.getText())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-400761d8fdb4> in <module>()
# ----> 1 from googlesearch.googlesearch import GoogleSearch
#       2 response = GoogleSearch().search("something")
#       3 for result in response.results:
#       4     print("Title: " + result.title)
#       5     print("Content: " + result.getText())
#
# ModuleNotFoundError: No module named 'googlesearch'

# %%
# %%cmd
# pip install google
# Out:
# Microsoft Windows [Version 10.0.16299.125]
# (c) 2017 Microsoft Corporation. All rights reserved.
#
# (C:\Users\AsusGo\Anaconda3) C:\Users\AsusGo\Downloads>pip install google
# ...
#
# (C:\Users\AsusGo\Anaconda3) C:\Users\AsusGo\Downloads>

# %%
from google import search,filter_result
for url in search('"Breaking Code" WordPress blog', stop=20):
    print(url)
filter_result("https://wordpress.org/tags/breaking-code")

# %% [markdown]
# References:
#
# Image Resource: https://creately.com/diagram/example/hfpfd0mk3/simple%20search%20engine%20
# https://backlinko.com/google-ranking-factors
# https://www.techhelp.ca/blog/google-bing-yahoo-compare/(ages of search engines)
# http://www.seobook.com/relevancy/(basic information about google yahoo bing search engines)
# https://en.wikipedia.org/wiki/Bingbot
# https://en.wikipedia.org/wiki/Googlebot
# https://www.digitalocean.com/community/tutorials/how-to-scrape-web-pages-with-beautiful-soup-and-python-3#pulling-text-from-a-web-page
# http://www.seochat.com/c/a/search-engine-spiders-help/the-yahoo-slurp-crawler/
# https://www.las.org.sg/sjlim/SJLIM20094Sampath.pdf
# https://stackoverflow.com/questions/6594620/python-3-2-unable-to-import-urllib2-importerror-no-module-named-urllib2
# https://stackoverflow.com/questions/28906859/module-has-no-attribute-urlencode

# %% [markdown]
# Refer:
# https://github.com/shusrushabezugam/big-data-python-class/blob/master/BEZUGAM_FinalProject_Analysing%2BSearch%2Bengines%2Bbased%2Bon%2Bsingle%2Bword%2Cmultiple%2Bwords%2Band%2Bnot%2Bpopular%2Bqueries.ipynb
